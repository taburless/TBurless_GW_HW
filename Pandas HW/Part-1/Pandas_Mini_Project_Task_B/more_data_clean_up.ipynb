# %%
# Dependencies
import pandas as pd

# %%
# load CSV
csv_path = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
more_clean_data = pd.read_csv(csv_path)
more_clean_data.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
more_reduced_clean = more_clean_data.iloc[:,[ 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
more_reduced_clean.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively
more_reduced_clean = more_reduced_clean.replace({0.0: "No", 1.0: "Yes"})
more_reduced_clean.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#   ChildrenNumber                 CityPopulation  ...  \
# 0            NaN  between 100,000 and 1 million  ...
# 1            NaN  between 100,000 and 1 million  ...
# ...

# %%
# Extract rows for only those who attended a bootcamp
more_attended = more_reduced_clean.loc[more_reduced_clean["AttendedBootcamp"] == "Yes"]
more_attended.count()
# Out:
# Age                     818
# AttendedBootcamp        953
# BootcampFinish          933
# BootcampFullJobAfter    635
# BootcampLoanYesNo       934
# BootcampName            895
# BootcampPostSalary      330
# BootcampRecommend       937
# ChildrenNumber          148
# CityPopulation          823
# CodeEventBootcamp        27
# CountryLive             825
# EmploymentField         476
# EmploymentStatus        792
# Gender                  833
# HasChildren             211
# HoursLearning           925
# Income                  430
# JobRoleInterest         402
# SchoolDegree            832
# SchoolMajor             622
# dtype: int64

# %%
more_rec = more_reduced_clean.loc[more_reduced_clean["BootcampRecommend"] == "Yes"]
more_rec.count()
# Out:
# Age                     642
# AttendedBootcamp        736
# BootcampFinish          729
# BootcampFullJobAfter    475
# BootcampLoanYesNo       729
# BootcampName            696
# BootcampPostSalary      282
# BootcampRecommend       736
# ChildrenNumber          113
# CityPopulation          642
# CodeEventBootcamp        23
# CountryLive             645
# EmploymentField         380
# EmploymentStatus        615
# Gender                  651
# HasChildren             161
# HoursLearning           719
# Income                  339
# JobRoleInterest         304
# SchoolDegree            650
# SchoolMajor             484
# dtype: int64

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
#group_bootcamp = more_attended.groupby('BootcampName')
#group_bootcamp
#count_bootcamp = group_bootcamp['BootcampName'].count()
#count_bootcamp
att_bootcamp = more_attended.groupby(["BootcampName"]).count()["AttendedBootcamp"].rename("Attended the Bootcamp")

bootcamp_data_attend = pd.DataFrame({"Attended the Bootcamp": att_bootcamp })
bootcamp_data_attend.head(10)
# Out:
#                           Attended the Bootcamp
# BootcampName
# 10x.org.il                                    5
# 4Geeks Academy                                8
# AcadGild                                      2
# Academia de Código                            4
# Academic Work Academy                         1
# Academy X                                     1
# Ada                                           9
# Alphappl                                      1
# AngelHack Education                           1
# Anyone Can Learn To Code                      7

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
rec_bootcamp = more_rec.groupby(["BootcampName"]).count()["BootcampRecommend"].rename("Recommends the Bootcamp")

bootcamp_data_recommend = pd.DataFrame({"Recommends the Bootcamp": rec_bootcamp })
bootcamp_data_recommend.head(10)
# Out:
#                           Recommends the Bootcamp
# BootcampName
# 10x.org.il                                      3
# 4Geeks Academy                                  4
# AcadGild                                        2
# Academia de Código                              4
# Ada                                             8
# AngelHack Education                             1
# Anyone Can Learn To Code                        5
# App Academy                                    20
# Austin Coding Academy                           1
# Base10 Academy                                  1

# %%
# Merge the two created data frames on the name of tbe bootcamp
merge_table = pd.merge(bootcamp_data_attend, bootcamp_data_recommend, on="BootcampName")
merge_table.head(10)
# Out:
#                           Attended the Bootcamp  Recommends the Bootcamp
# BootcampName
# 10x.org.il                                    5                        3
# 4Geeks Academy                                8                        4
# AcadGild                                      2                        2
# Academia de Código                            4                        4
# Ada                                           9                        8
# AngelHack Education                           1                        1
# Anyone Can Learn To Code                      7                        5
# App Academy                                  22                       20
# Austin Coding Academy                         1                        1
# Base10 Academy                                1                        1

# %%
# Calculate percentage of eac bootcamp's students who are recommenders
merge_table['Result'] = (merge_table['Recommends the Bootcamp']/merge_table['Attended the Bootcamp']).map("{0:,.2f}%".format)
merge_table.head(10)
# Out:
#                           Attended the Bootcamp  Recommends the Bootcamp  \
# BootcampName
# 10x.org.il                                    5                        3
# 4Geeks Academy                                8                        4
# AcadGild                                      2                        2
# Academia de Código                            4                        4
# Ada                                           9                        8
# AngelHack Education                           1                        1
# Anyone Can Learn To Code                      7                        5
# App Academy                                  22                       20
# Austin Coding Academy                         1                        1
# Base10 Academy                                1                        1
#
#                          Result
# BootcampName
# 10x.org.il                0.60%
# 4Geeks Academy            0.50%
# AcadGild                  1.00%
# ...

# %%
# Export to excel and remove index
export_excel = merge_table.to_excel (r'Resources/more_data_finished.xlsx', index = None, header=True)
