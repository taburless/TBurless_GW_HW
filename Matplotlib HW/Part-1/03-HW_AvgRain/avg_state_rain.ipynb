# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
avg_rain_df = pd.read_csv("Resources/avg_rain_state.csv")
avg_rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(avg_rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(10,3))
plt.bar(x_axis, avg_rain_df["Inches"], color='y', alpha=0.75, align="edge")
plt.xticks(tick_locations, avg_rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ([<matplotlib.axis.XTick at 0x124499206d8>,
# ...
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(0, len(x_axis))
plt.ylim(0, max(avg_rain_df["Inches"]+10))
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain Fall per State")
plt.ylabel("Rainfall(Inches)")
plt.xlabel("States")
# Out:
# Text(0.5, 0, 'States')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/avg_state_rain_HW.png")
plt.show()
